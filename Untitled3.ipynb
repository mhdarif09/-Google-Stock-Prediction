# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/trainset.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-01-02  357.385559  361.151062  355.959839  359.288177  359.288177
# 1  2013-01-03  360.122742  363.600128  358.031342  359.496826  359.496826
# 2  2013-01-04  362.313507  368.339294  361.488861  366.600616  366.600616
# 3  2013-01-07  365.348755  367.301056  362.929504  365.001007  365.001007
# 4  2013-01-08  365.393463  365.771027  359.874359  364.280701  364.280701
#
#     Volume
# 0  5115500
# 1  4666500
# 2  5562800
# 3  3332900
# 4  3373900

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean    652.704082   657.475653   647.433700   652.657015   652.657015
# std     175.630574   176.627416   174.732814   175.820993   175.820993
# min     350.053253   350.391052   345.512787   349.164032   349.164032
# 25%     528.287079   532.615204   524.232483   528.429413   528.429413
# 50%     600.002563   603.236511   594.453674   598.005554   598.005554
# 75%     774.015015   779.120025   768.662506   772.720001   772.720001
# max    1075.199951  1078.489990  1063.550049  1077.140015  1077.140015
#
#              Volume
# count  1.259000e+03
# mean   2.414928e+06
# std    1.672160e+06
# min    7.900000e+03
# 25%    1.336900e+06
# 50%    1.842300e+06
# 75%    3.090850e+06
# max    2.328310e+07

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   object
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 69.0+ KB

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

# Create subplots and mention plot grid size
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
               vertical_spacing=0.08, subplot_titles=('GOOGL', 'Volume'), 
               row_width=[0.2, 0.7])

# Plot data 
fig.add_trace(go.Candlestick(x=df["Date"], open=df["Open"], high=df["High"],
                low=df["Low"], close=df["Close"], name="GOOGL"), 
                row=1, col=1)

fig.update_layout(
    title="Google Stock",
    yaxis_title="GOOGL Stock Price")

# Plot volume
fig.add_trace(go.Bar(x=df['Date'], y=df['Volume'], showlegend=False), row=2, col=1)

fig.update(layout_xaxis_rangeslider_visible=False)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="675a00cb-b3ff-488b-967e-e82d22b89485" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("675a00cb-b3ff-488b-967e-e82d22b89485")) {                    Plotly.newPlot(                        "675a00cb-b3ff-488b-967e-e82d22b89485",                        [{"close":[359.288177,359.496826,366.600616,365.001007,364.280701,366.67514,368.344269,367.604095,359.288177,360.122742,355.28421,353.361725,349.978729,349.164032,368.354218,374.668152,374.399902,372.939392,374.404846,374.47937,375.403351,385.294037,377.057617,380.395905,382.596588,384.474365,390.147461,388.682007,387.827545,388.900574,391.364563,393.883179,400.818054,393.669556,395.194641,397.271149,392.830017,392.512085,397.305908,398.011322,400.490204,408.095734,416.590485,413.003815,413.609863,413.073364,414.712708,411.130981,409.988434,408.115601,404.518982,401.285034,403.038635,404.722656,403.00882,402.536896,402.204041,403.585083,398.736603,394.528961,398.006348,403.893066,400.495178,394.966125,388.994965,384.921448,386.312408,392.536926,392.641235,392.472351,388.438568,394.121
_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train
# Out:
# array([[[0.01011148]],
#
#        [[0.01388614]],
#
#        [[0.01690727]],
#
#        ...,
#
#        [[0.9805695 ]],
#
#        [[0.97637719]],
#
#        [[0.97543954]]])

# %%
y_train
# Out:
# array([0.01388614, 0.01690727, 0.02109298, ..., 0.97637719, 0.97543954,
#        0.9674549 ])

# %%
print(f"Shape of X_train: {X_train.shape}\nShape of y_train: {y_train.shape}")
# Out:
# Shape of X_train: (1257, 1, 1)
# Shape of y_train: (1257,)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
model = Sequential()
model.add(LSTM(units = 50,return_sequences = True,input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50,return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50,return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
model.add(Dense(units = 1))

# %%
model.compile(optimizer = 'adam',loss = 'mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 1, 50)             10400
#
#  dropout_8 (Dropout)         (None, 1, 50)             0
#
#  lstm_9 (LSTM)               (None, 1, 50)             20200
#
#  dropout_9 (Dropout)         (None, 1, 50)             0
#
#  lstm_10 (LSTM)              (None, 1, 50)             20200
#
#  dropout_10 (Dropout)        (None, 1, 50)             0
#
#  lstm_11 (LSTM)              (None, 50)                20200
#
#  dropout_11 (Dropout)        (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train.reshape(-1,1), epochs=100)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 7s 6ms/step - loss: 0.1593
# Epoch 2/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0395
# Epoch 3/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0151
# Epoch 4/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0069
# Epoch 5/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0061
# Epoch 6/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0049
# Epoch 7/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0048
# Epoch 8/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0044
# Epoch 9/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0038
# Epoch 10/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0038
# Epoch 11/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 12/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0030
# Epoch 13/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0028
# Epoch 14/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0030
# Epoch 15/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 16/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0024
# Epoch 17/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 18/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 19/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 20/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 21/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 22/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 23/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 24/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 25/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 26/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 27/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 28/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 29/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 30/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 31/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 32/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 33/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 34/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 35/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 36/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 37/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 38/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 39/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 40/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 41/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 42/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 43/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 44/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 45/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 46/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 47/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 48/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 49/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 50/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 51/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 52/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 53/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 54/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 55/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 56/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 57/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 58/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 59/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 60/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 61/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 62/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 63/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 64/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 65/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 66/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 67/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 68/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 69/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 70/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 71/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 72/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 73/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 74/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 75/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 76/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 77/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 78/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 79/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 80/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 81/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 82/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 83/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 84/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 85/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 86/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 87/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 88/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 89/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 90/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 91/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 92/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 93/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 94/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 95/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 96/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 97/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 98/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 99/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 100/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0014

# %%
test_data = pd.read_csv('/content/testset.csv')
test_data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2018-01-02  1048.339966  1066.939941  1045.229980  1065.000000
# 1  2018-01-03  1064.310059  1086.290039  1063.209961  1082.479980
# 2  2018-01-04  1088.000000  1093.569946  1084.001953  1086.400024
# 3  2018-01-05  1094.000000  1104.250000  1092.000000  1102.229980
# 4  2018-01-08  1102.229980  1111.270020  1101.619995  1106.939941
#
#      Adj Close   Volume
# 0  1065.000000  1237600
# 1  1082.479980  1430200
# 2  1086.400024  1004600
# 3  1102.229980  1279100
# 4  1106.939941  1047600

# %%
real_stock_price = test_data.loc[:, ["Open"]].values
real_stock_price
# Out:
# array([[1048.339966],
#        [1064.310059],
#        [1088.      ],
#        [1094.      ],
#        [1102.22998 ],
#        [1109.400024],
#        [1097.099976],
#        [1106.300049],
#        [1102.410034],
#        [1132.51001 ],
#        [1126.219971],
#        [1131.410034],
#        [1131.829956],
#        [1137.48999 ],
#        [1159.849976],
#        [1177.329956],
#        [1172.530029],
#        [1175.079956],
#        [1176.47998 ],
#        [1167.829956],
#        [1170.569946],
#        [1162.609985],
#        [1122.      ],
#        [1090.599976],
#        [1027.180054],
#        [1081.540039],
#        [1055.410034],
#        [1017.25    ],
#        [1048.      ],
#        [1045.      ],
#        [1048.949951],
#        [1079.069946],
#        [1088.410034],
#        [1090.569946],
#        [1106.469971],
#        [1116.189941],
#        [1112.640015],
#        [1127.800049],
#        [1141.23999 ],
#        [1123.030029],
#        [1107.869995],
#        [1053.079956],
#        [1075.140015],
#        [1099.219971],
#        [1089.189941],
#        [1115.319946],
#        [1136.      ],
#        [1163.849976],
#        [1170.      ],
#        [1145.209961],
#        [1149.959961],
#        [1154.140015],
#        [1120.01001 ],
#        [1099.      ],
#        [1092.73999 ],
#        [1081.880005],
#        [1047.030029],
#        [1046.      ],
#        [1063.      ],
#        [ 998.      ],
#        [1011.630005],
#        [1022.820007],
#        [1013.909973],
#        [ 993.409973],
#        [1041.329956],
#        [1020.      ],
#        [1016.799988],
#        [1026.439941],
#        [1027.98999 ],
#        [1025.040039],
#        [1040.880005],
#        [1037.      ],
#        [1051.369995],
#        [1077.430054],
#        [1069.400024],
#        [1082.      ],
#        [1077.859985],
#        [1052.      ],
#        [1025.52002 ],
#        [1029.51001 ],
#        [1046.      ],
#        [1030.01001 ],
#        [1013.659973],
#        [1028.099976],
#        [1019.      ],
#        [1016.900024],
#        [1049.22998 ],
#        [1058.540039],
#        [1058.099976],
#        [1086.030029],
#        [1093.599976],
#        [1100.      ],
#        [1090.      ],
#        [1077.310059],
#        [1079.890015],
#        [1061.859985],
#        [1074.060059],
#        [1083.560059],
#        [1065.130005],
#        [1079.      ],
#        [1079.02002 ],
#        [1064.890015],
#        [1063.030029],
#        [1067.560059],
#        [1099.349976],
#        [1122.329956],
#        [1140.98999 ],
#        [1142.170044],
#        [1131.319946],
#        [1118.180054],
#        [1118.599976],
#        [1131.069946],
#        [1141.119995],
#        [1143.849976],
#        [1148.859985],
#        [1143.650024],
#        [1158.5     ],
#        [1175.310059],
#        [1174.849976],
#        [1159.140015],
#        [1143.599976],
#        [1128.      ],
#        [1121.339966],
#        [1102.089966],
#        [1120.      ]])

# %%
dataset_total = pd.concat((df['Open'], test_data['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test_data) - timesteps:].values.reshape(-1,1)
inputs = scaler.transform(inputs)  # min max scaler
inputs
# Out:
# array([[0.96072522],
#        [0.96295924],
#        [0.9849825 ],
#        [1.01765167],
#        [1.02592586],
#        [1.03727526],
#        [1.04716297],
#        [1.03020082],
#        [1.04288801],
#        [1.03752356],
#        [1.07903237],
#        [1.0703582 ],
#        [1.07751546],
#        [1.07809455],
#        [1.08589991],
#        [1.11673503],
#        [1.14084047],
#        [1.13422122],
#        [1.13773765],
#        [1.13966833],
#        [1.12773968],
#        [1.13151821],
#        [1.12054117],
#        [1.06453873],
#        [1.02123712],
#        [0.93377906],
#        [1.00874318],
#        [0.97270908],
#        [0.9200852 ],
#        [0.96249042],
#        [0.95835332],
#        [0.96380043],
#        [1.00533684],
#        [1.01821712],
#        [1.0211957 ],
#        [1.04312234],
#        [1.05652648],
#        [1.05163102],
#        [1.07253718],
#        [1.09107128],
#        [1.06595918],
#        [1.04505301],
#        [0.96949583],
#        [0.99991735],
#        [1.03312436],
#        [1.01929263],
#        [1.05532673],
#        [1.08384517],
#        [1.12225116],
#        [1.13073224],
#        [1.096546  ],
#        [1.10309639],
#        [1.10886082],
#        [1.06179447],
#        [1.03282101],
#        [1.02418826],
#        [1.009212  ],
#        [0.9611528 ],
#        [0.95973235],
#        [0.98317589],
#        [0.89353885],
#        [0.91233505],
#        [0.92776642],
#        [0.9154792 ],
#        [0.88720906],
#        [0.95329222],
#        [0.92387754],
#        [0.91946462],
#        [0.93275842],
#        [0.93489599],
#        [0.93082791],
#        [0.95267172],
#        [0.94732107],
#        [0.96713774],
#        [1.00307538],
#        [0.99200172],
#        [1.00937748],
#        [1.00366827],
#        [0.96800654],
#        [0.93148982],
#        [0.93699214],
#        [0.95973235],
#        [0.93768166],
#        [0.91513444],
#        [0.93504766],
#        [0.92249851],
#        [0.91960258],
#        [0.9641866 ],
#        [0.97702546],
#        [0.9764186 ],
#        [1.01493502],
#        [1.02537421],
#        [1.03420004],
#        [1.02040973],
#        [1.0029099 ],
#        [1.00646775],
#        [0.98160377],
#        [0.99842805],
#        [1.01152885],
#        [0.98611323],
#        [1.00524039],
#        [1.00526799],
#        [0.98578228],
#        [0.9832173 ],
#        [0.98946435],
#        [1.03330364],
#        [1.06499375],
#        [1.09072652],
#        [1.09235385],
#        [1.07739123],
#        [1.05927091],
#        [1.05984999],
#        [1.07704647],
#        [1.0909058 ],
#        [1.09467053],
#        [1.10157949],
#        [1.09439479],
#        [1.11487338],
#        [1.13805497],
#        [1.1374205 ],
#        [1.11575598],
#        [1.09432578],
#        [1.07281292],
#        [1.06362853],
#        [1.03708217],
#        [1.06178067]])
